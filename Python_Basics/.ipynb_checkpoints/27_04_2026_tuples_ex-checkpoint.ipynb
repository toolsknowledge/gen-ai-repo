# %%
# t1 = ()                                       
# print(t1)
# t2 = (10,20,30,40,50)
# print(t2)
# t3 = (10,10.1,"hello",True)
# print(t3)
# t4 = tuple((10,20,30,40,50))
# print(t4)
# print(type(t1))
# t5=(10)
# print(type(t5))
# t6=(10,)
# print(type(t6))
# t7=10,20,30
# print(type(t7))
# t8=10,
# print(type(t8))

# %%
# t1 = (10,20,30,40,50)
# print(t1[0])
# print(t1[-5])
# print(t1[0:3])
# print(t1[:2])
# print(t1[2:])
# print(t1[0:4:2])
# print(t1[::-2])

# %%
# t1 = (10,20,30,40,50)
# t1[0] = 100

# %%
# t1 = (10,20,30,40,50)
# list1 = list(t1)
# list1[0] = 100
# t1 = tuple(list1)
# print(t1)

# %%
# t1 = (10,20,30,40,50)
# e1,e2,e3,e4,e5 = t1
# print(e5)
# e1, *t2, e5 = t1
# t2 = tuple(t2)
# print(t2)
# e2, *t3 = t2
# e3,e4 = t3
# print(e2,e3,e4)
# e1,*t2,e4,e5 = t1
# print(e4,e5)
# *t2, e1,e2 = t1;
# print(t2)

# %%
# t1 = (10,20,30,10,20,30)
# print( t1.count(10) )
# print( t1.count(100) )

# %%
# t1 = (10,20,30,10,20,30)
# print(t1.index(10))
# print(t1.index(40))

# %%
# t1 = (10,20,30,10,20,30)
# print(f"Number of Tuple Elements : {len(t1)}")
# print(f"Max Element : {max(t1)}")
# print(f"Min Element : {min(t1)}")
# print(f"Sum of Elements : {sum(t1)}")

# %%
# t1 = (10,20,30)
# t2 = (40,50,60)
# t3 = t1 + t2
# print(t3)
# t4 = t3*2
# print(t4)
# print(20 in t1)
# print(200 not in t1)

# %%
# t1 = (10,20,30,40,50)
# for element in t1:
#     print(element)

# %%
# nested_tuples = ((1,"Agentic AI"),(2,"Gen AI"),(3,"NLP"))
# for inner_tuples in nested_tuples:
#     for element in inner_tuples:
#         print(element)

# %%
# import sys
# list1 = [10,20,30,40,50]
# tuple1 = (10,20,30,40,50)
# print(sys.getsizeof(list1))
# print(sys.getsizeof(tuple1))

# %%
# d1 = {
#     (10,) : 10,
#     [10] : 10
# }
# print(d1)

# %%
# def test_func():
#     return 101,"Agentic AI","High",5

# res = test_func()
# sid,sname,sdemand,srating = res
# print(res)
# print(sid,sname,sdemand,srating)

# %%
# print( tuple(x for x in range(10)) )

# %%
t1 = (10,20,30,40,50)
for index,value in enumerate(t1):
    print(index,value)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50
