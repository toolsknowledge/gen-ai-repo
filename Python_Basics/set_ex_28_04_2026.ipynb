# %%
# Set
# in-built python data structure
# wont allows duplicates
# unordered
# no indexes
# Mutable
# Ex.Fast searching
# {}
# hashing

# %%
# s1 = set()
# print(type(s1))
# s2 = {}
# print(type(s2))

# %%
# s1 = {10,20,30,10,20,30}
# print(s1)
# s2 = set([10,20,30,10,20,30]) # convert list to set
# print(s2)
# s3 = set({10,20,30,10,20,30})
# print(s3)

# %%
# s1 = {1,2}
# s1.add(3)
# print(s1)
# s1.update([4,5])
# s1.update({6,7})
# print(s1)

# %%
# s1 = {10,20,30,40,50}
# s1.remove(10)
# print(s1)
# s1.remove(10)

# s1.discard(10)
# print(s1)
# print(s1.discard(10))
# print(s1)

# s1.pop()
# print(s1)

# s1.clear()
# print(s1)

# %%
# s1 = {10,20,30}
# s2 = {30,40,50}
# print(s1.union(s2))
# print(s1 | s2)

# print(s1.intersection(s2))
# print(s1 & s2)

# print(s2.difference(s1))
# print(s1 - s2)

# print(s1.symmetric_difference(s2))
# print(s2.symmetric_difference(s1))
# print(s1^s2)
# print(s2^s1)

# print(s1)
# print(s1.intersection_update(s2))
# print(s1)

# %%
# s1 = {10,20,30,40,50}
# print(30 in s1)
# print(300 not in s1)

# %%
# s1 = {10,20,30,40,50}
# for value in s1:
#     print(value)

# list1 = list(s1)
# for value in list1:
#     print(value)

# for key,value in enumerate(list1):
#     print(key,value)

# iterator = iter(s1)
# print(next(iterator))
# print(next(iterator))
# print(next(iterator))
# print(next(iterator))
# print(next(iterator))
# print(next(iterator))

# %%
# set - tuple
# tuple()
s1 = {10,20,30}
t1 = tuple(s1)
print(t1)
# Out:
# (10, 20, 30)
